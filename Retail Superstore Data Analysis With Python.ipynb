# %% [markdown]
# # Retail Superstore Data Analysis With Python
# ## Created And Done By "Anubhav Kumar Gupta"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.size
# Out:
# 129922

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.strip()

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['ship_mode', 'segment', 'country', 'city', 'state', 'postal_code',
#        'region', 'category', 'sub-category', 'sales', 'quantity', 'discount',
#        'profit'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df[df.duplicated(subset=df.columns,keep=False)]
# Out:
#            ship_mode      segment        country           city         state  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# ...

# %%
df.drop_duplicates(subset=df.columns,keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(subset=df.columns,keep=False)]
# Out:
# Empty DataFrame
# Columns: [ship_mode, segment, country, city, state, postal_code, region, category, sub-category, sales, quantity, discount, profit]
# Index: []

# %%
df.isna().sum()
# Out:
# ship_mode       0
# segment         0
# country         0
# city            0
# state           0
# postal_code     0
# region          0
# category        0
# sub-category    0
# sales           0
# quantity        0
# discount        0
# profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ship_mode     9977 non-null   object
#  1   segment       9977 non-null   object
#  2   country       9977 non-null   object
#  3   city          9977 non-null   object
#  4   state         9977 non-null   object
#  5   postal_code   9977 non-null   int64
#  6   region        9977 non-null   object
#  7   category      9977 non-null   object
#  8   sub-category  9977 non-null   object
#  9   sales         9977 non-null   float64
#  10  quantity      9977 non-null   int64
#  11  discount      9977 non-null   float64
#  12  profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#         postal_code         sales     quantity     discount      profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
sns.countplot(data=df,y='ship_mode')
# Out:
# <AxesSubplot: xlabel='count', ylabel='ship_mode'>

# %%
sns.countplot(data=df,y='segment')
# Out:
# <AxesSubplot: xlabel='count', ylabel='segment'>

# %%
sns.countplot(data=df,y='country')
# Out:
# <AxesSubplot: xlabel='count', ylabel='country'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,y='state')
# Out:
# <AxesSubplot: xlabel='count', ylabel='state'>

# %%
sns.countplot(data=df,y='region')
# Out:
# <AxesSubplot: xlabel='count', ylabel='region'>

# %%
sns.countplot(data=df,y='category')
# Out:
# <AxesSubplot: xlabel='count', ylabel='category'>

# %%
sns.countplot(data=df,y='sub-category')
# Out:
# <AxesSubplot: xlabel='count', ylabel='sub-category'>

# %%
sns.countplot(data=df,hue='category',y='sub-category')
# Out:
# <AxesSubplot: xlabel='count', ylabel='sub-category'>

# %%
sns.countplot(data=df,y='region',hue='category')
# Out:
# <AxesSubplot: xlabel='count', ylabel='region'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,y='state',hue='category')
# Out:
# <AxesSubplot: xlabel='count', ylabel='state'>

# %%
sns.countplot(data=df,hue='ship_mode',y='region')
# Out:
# <AxesSubplot: xlabel='count', ylabel='region'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,hue='ship_mode',y='state')
# Out:
# <AxesSubplot: xlabel='count', ylabel='state'>

# %%
df_state=df.groupby(['state']).agg({'sales':sum}).rename(columns={'sales':'sales_sum_states'})

# %%
df_state.sort_values(by='sales_sum_states',ascending=False).head()
# Out:
#               sales_sum_states
# state
# California         457576.2715
# New York           310827.1510
# Texas              170124.5418
# Washington         138560.8100
# Pennsylvania       116496.3620

# %%
df_state.sort_values(by='sales_sum_states',ascending=False).tail()
# Out:
#                sales_sum_states
# state
# Wyoming                1603.136
# South Dakota           1315.560
# Maine                  1270.530
# West Virginia          1209.824
# North Dakota            919.910

# %%
df_city=df.groupby(['city']).agg({'sales':sum}).rename(columns={'sales':'sales_sum_city'})

# %%
df_city.sort_values(by='sales_sum_city',ascending=False).head()
# Out:
#                sales_sum_city
# city
# New York City      256319.041
# Los Angeles        175831.901
# Seattle            119460.282
# San Francisco      112577.172
# Philadelphia       109061.461

# %%
df_city.sort_values(by='sales_sum_city',ascending=False).tail()
# Out:
#               sales_sum_city
# city
# Ormond Beach           2.808
# Pensacola              2.214
# Jupiter                2.064
# Elyria                 1.824
# Abilene                1.392

# %%
df_state_city=df.groupby(['state','city']).agg({'sales':sum}).rename(columns={'sales':'sales_sum_states_city'})

# %%
df_state_city.sort_values(by='sales_sum_states_city',ascending=False).head()
# Out:
#                             sales_sum_states_city
# state        city
# New York     New York City             256319.041
# California   Los Angeles               175831.901
# Washington   Seattle                   119460.282
# California   San Francisco             112577.172
# Pennsylvania Philadelphia              109061.461

# %%
df_state_city.sort_values(by='sales_sum_states_city',ascending=False).tail()
# Out:
#                       sales_sum_states_city
# state   city
# Florida Ormond Beach                  2.808
#         Pensacola                     2.214
#         Jupiter                       2.064
# Ohio    Elyria                        1.824
# Texas   Abilene                       1.392

# %%
df_state=df.groupby(['state']).agg({'profit':sum}).rename(columns={'profit':'profit_sum_states'})

# %%
df_state.sort_values(by='profit_sum_states',ascending=False).head()
# Out:
#             profit_sum_states
# state
# California         76330.7891
# New York           74015.4622
# Washington         33368.2375
# Michigan           24428.0903
# Virginia           18597.9504

# %%
df_state.sort_values(by='profit_sum_states',ascending=False).tail()
# Out:
#                 profit_sum_states
# state
# North Carolina         -7490.9122
# Illinois              -12601.6500
# Pennsylvania          -15565.4035
# Ohio                  -16959.3178
# Texas                 -25750.9833

# %%
df_state[df_state['profit_sum_states']<0]
# Out:
#            profit_sum_states
# city
# Abilene              -3.7584
# Akron              -186.6356
# Allen               -39.8775
# Allentown          -226.4504
# Altoona              -1.1835
# ...                      ...
# Waco               -520.1034
# Wheeling           -107.3962
# Wilson              -14.3360
# York               -102.1692
# Yuma               -465.9909
#
# [116 rows x 1 columns]

# %%
df_city=df.groupby(['city']).agg({'profit':sum}).rename(columns={'profit':'profit_sum_city'})

# %%
df_city.sort_values(by='profit_sum_city',ascending=False).head()
# Out:
#                profit_sum_city
# city
# New York City       62013.8973
# Los Angeles         30431.4267
# Seattle             29121.6825
# San Francisco       17466.1186
# Detroit             13146.6935

# %%
df_city.sort_values(by='profit_sum_city',ascending=False).tail()
# Out:
#               profit_sum_city
# city
# Chicago            -6648.3318
# Lancaster          -7239.0684
# San Antonio        -7299.0502
# Houston           -10175.1755
# Philadelphia      -13843.2106

# %%
df_city[df_city['profit_sum_city']<0]
# Out:
#            profit_sum_city
# city
# Abilene            -3.7584
# Akron            -186.6356
# Allen             -39.8775
# Allentown        -226.4504
# Altoona            -1.1835
# ...                    ...
# Waco             -520.1034
# Wheeling         -107.3962
# Wilson            -14.3360
# York             -102.1692
# Yuma             -465.9909
#
# [116 rows x 1 columns]

# %%
df_state_city=df.groupby(['state','city']).agg({'profit':sum}).rename(columns={'profit':'profit_sum_states_city'})

# %%
df_state_city.sort_values(by='profit_sum_states_city',ascending=False).head()
# Out:
#                           profit_sum_states_city
# state      city
# New York   New York City              62013.8973
# California Los Angeles                30431.4267
# Washington Seattle                    29121.6825
# California San Francisco              17466.1186
# Michigan   Detroit                    13146.6935

# %%
df_state_city.sort_values(by='profit_sum_states_city',ascending=False).tail()
# Out:
#                            profit_sum_states_city
# state        city
# Illinois     Chicago                   -6648.3318
# Ohio         Lancaster                 -7149.6180
# Texas        San Antonio               -7299.0502
#              Houston                  -10175.1755
# Pennsylvania Philadelphia             -13843.2106

# %%
df_state_city[df_state_city['profit_sum_states_city']<0]
# Out:
#                      profit_sum_states_city
# state   city
# Arizona Mesa                      -559.2314
#         Peoria                     -55.1076
#         Phoenix                  -2790.8832
#         Scottsdale                 -89.4879
#         Tucson                     -64.9668
# ...                                     ...
# Texas   San Angelo                 -58.5532
#         San Antonio              -7299.0502
#         San Marcos                 -19.3413
#         Tyler                     -443.7086
#         Waco                      -520.1034
#
# [138 rows x 1 columns]

# %%
df_state=df.groupby(['state']).agg({'quantity':sum}).rename(columns={'quantity':'quantity_sum_states'})

# %%
df_state.sort_values(by='quantity_sum_states',ascending=False).head()
# Out:
#               quantity_sum_states
# state
# California                   7649
# New York                     4220
# Texas                        3718
# Pennsylvania                 2150
# Washington                   1871

# %%
df_state.sort_values(by='quantity_sum_states',ascending=False).tail()
# Out:
#                       quantity_sum_states
# state
# District of Columbia                   40
# Maine                                  35
# North Dakota                           30
# West Virginia                          18
# Wyoming                                 4

# %%
df_state[df_state['quantity_sum_states']<50]
# Out:
#                       quantity_sum_states
# state
# District of Columbia                   40
# Maine                                  35
# North Dakota                           30
# South Dakota                           42
# West Virginia                          18
# Wyoming                                 4

# %%
df_city=df.groupby(['city']).agg({'quantity':sum}).rename(columns={'quantity':'quantity_sum_city'})

# %%
df_city.sort_values(by='quantity_sum_city',ascending=False).head()
# Out:
#                quantity_sum_city
# city
# New York City               3413
# Los Angeles                 2876
# Philadelphia                1978
# San Francisco               1920
# Seattle                     1578

# %%
df_city.sort_values(by='quantity_sum_city',ascending=False).tail()
# Out:
#              quantity_sum_city
# city
# Iowa City                    1
# Port Orange                  1
# Lindenhurst                  1
# Littleton                    1
# Elyria                       1

# %%
df_city[df_city['quantity_sum_city']<50]
# Out:
#             quantity_sum_city
# city
# Aberdeen                    3
# Abilene                     2
# Allen                      13
# Allentown                  20
# Altoona                     9
# ...                       ...
# Woodstock                  31
# Woonsocket                 15
# York                       19
# Yucaipa                     5
# Yuma                       22
#
# [408 rows x 1 columns]

# %%
df_state_city=df.groupby(['state','city']).agg({'quantity':sum}).rename(columns={'quantity':'quantity_sum_states_city'})

# %%
df_state_city.sort_values(by='quantity_sum_states_city',ascending=False).head()
# Out:
#                             quantity_sum_states_city
# state        city
# New York     New York City                      3413
# California   Los Angeles                        2876
# Pennsylvania Philadelphia                       1978
# California   San Francisco                      1920
# Washington   Seattle                            1578

# %%
df_state_city.sort_values(by='quantity_sum_states_city',ascending=False).tail()
# Out:
#                         quantity_sum_states_city
# state      city
# Washington Everett                             1
# New York   Lindenhurst                         1
# Ohio       Elyria                              1
# Florida    Jupiter                             1
#            Port Orange                         1

# %%
df_state_city[df_state_city['quantity_sum_states_city']<50]
# Out:
#                       quantity_sum_states_city
# state     city
# Alabama   Auburn                            16
#           Florence                          24
#           Hoover                            15
#           Huntsville                        40
#           Montgomery                        48
# ...                                        ...
# Wisconsin Superior                          37
#           Waukesha                           5
#           Wausau                            14
#           West Allis                         5
# Wyoming   Cheyenne                           4
#
# [463 rows x 1 columns]
